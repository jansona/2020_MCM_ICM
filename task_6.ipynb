# %%
import numpy
import pandas as pd
import numpy as np
import networkx as nx
from math import ceil
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('./results/long/Eigenvector centrality.csv')
data = data.rename(columns={'Eigenvector centrality':'EC'})

# %%
p = sns.distplot(data['EC'])
plt.ylabel('Amount')
f = p.get_figure()
f.savefig('./results/task6/EC_dist.png')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Program Files\Python37\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'EC'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-59f127d63b60> in <module>
# ----> 1 p = sns.distplot(data['EC'])
# ...

# %%
data = pd.read_csv('./results/long/Clustering coefficient.csv')
data = data.rename(columns={'Clustering coefficient':'ClusC'})

p = sns.distplot(data['ClusC'])
plt.ylabel('Amount')
f = p.get_figure()
f.savefig('./results/task6/ClusC_dist.png')
